# %% [markdown]
# # Preparing Data

# %% [markdown]
# ## Importing Libraries

# %%
# Import the pandas library.
import pandas as pd
# Import the numpy library.
import numpy as np

# Import the string library.
import string
# Import the punctuation library.
from string import punctuation
# Import the nltk library.
import nltk
# Import the stopwords.
from nltk.corpus import stopwords
# Download the stopwords
nltk.download("stopwords")

# Import the TensorFlow library.
import tensorflow as tf

# Import the Input, Dense, Dropout layers.
from tensorflow.keras.layers import Input, Dense, Dropout
# Import the Sequential model.
from tensorflow.keras.models import Sequential

# Import the sklearn library.
import sklearn
# Import the train_test_split model selection.
from sklearn.model_selection import train_test_split
# Import the CountVectorizer, TfidfTransformer, TfidfVectorizer.
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer

# Import the joblib library.
import joblib

# %% [markdown]
# # Cleaning the Data

# %% [markdown]
# ## Importing the Data

# %%
# Use the .read_csv function to read the "Reviews.csv" data into the notebook.
data=pd.read_csv("Reviews.csv")

# Use data.head() to print out the first few lines of data.
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ## Cleaning Up Data

# %%
# Add the 'UserId', 'Id', and 'Time' to the drop function to drop them.
data=data.drop(["UserId", "Id", "Time"],axis=1)

# Use dropna() to drop empty rows.
data.dropna(inplace=True)

# Print the first few lines of the data.
data.head()
# Out:
#     ProductId                      ProfileName  HelpfulnessNumerator  \
# 0  B001E4KFG0                       delmartian                     1
# 1  B00813GRG4                           dll pa                     0
# 2  B000LQOCH0  Natalia Corres "Natalia Corres"                     1
# 3  B000UA0QIQ                             Karl                     3
# 4  B006K2ZZ7K    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score                Summary  \
# 0                       1      5  Good Quality Dog Food
# 1                       0      1      Not as Advertised
# 2                       1      4  "Delight" says it all
# 3                       3      2         Cough Medicine
# 4                       0      5            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ## Adding a Polarity Column

# %%
# Create a new column to keep track of if the review is positive negative or neutral.
data["Polarity_Rating"]=data["Score"].apply(lambda x: "Positive" if x>3 else ("Neutral" if x==3 else "Negative"))

# Print the first few lines of the data.
data.head()
# Out:
#     ProductId                      ProfileName  HelpfulnessNumerator  \
# 0  B001E4KFG0                       delmartian                     1
# 1  B00813GRG4                           dll pa                     0
# 2  B000LQOCH0  Natalia Corres "Natalia Corres"                     1
# 3  B000UA0QIQ                             Karl                     3
# 4  B006K2ZZ7K    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score                Summary  \
# 0                       1      5  Good Quality Dog Food
# 1                       0      1      Not as Advertised
# 2                       1      4  "Delight" says it all
# 3                       3      2         Cough Medicine
# 4                       0      5            Great taffy
#
#                                                 Text Polarity_Rating
# 0  I have bought several of the Vitality canned d...        Positive
# 1  Product arrived labeled as Jumbo Salted Peanut...        Negative
# 2  This is a confection that has been around a fe...        Positive
# 3  If you are looking for the secret ingredient i...        Negative
# 4  Great taffy at a great price.  There was a wid...        Positive

# %% [markdown]
# ## Sampling the Data

# %%
# Separate the positive data into a group.
data_positive = data[data["Polarity_Rating"]=="Positive"]
# Separate the negative data into a group.
data_negative=data[data["Polarity_Rating"]=="Negative"]
# Separate the neutral data into a group.
data_neutral=data[data["Polarity_Rating"]=="Neutral"]

# Print out the shape of each list.
print(data_positive.shape)
print(data_negative.shape)
print(data_neutral.shape)
# Out:
# (443756, 8)
# (82007, 8)
# (42638, 8)

# %%
# Get a sample from the positive reviews.
data_positive=data_positive.sample(8000)
# Get a sample from the negative reviews.
data_negative=data_negative.sample(8000)
# Get a sample from the neutral reviews.
data_neutral=data_neutral.sample(8000)

# Print out the shape of the new lists.
print(data_positive.shape)
print(data_negative.shape)
print(data_neutral.shape)
# Out:
# (8000, 8)
# (8000, 8)
# (8000, 8)

# %%
# Combine the positive, negative, and neutral data lists together to create one large dataset.
data=pd.concat([data_positive, data_negative, data_neutral])

# Print the data's shape.
print(data.shape)
# Out:
# (24000, 8)

# %% [markdown]
# ## Cleaning up the Data

# %%
# Create a function called text_cleanup that returns the text without the stopwords and punctuation.
def text_cleanup(text):
    stopwrds = stopwords.words("english")
    no_punc = [char for char in text if char not in string.punctuation]
    no_punc="".join(no_punc)
    return " ".join([word for word in no_punc.split() if word.lower not in stopwrds])

# %%
# Create a new column called reviews that cleans up the text.
data["reviews"]=data["Text"].apply(text_cleanup)

# Print the first few lines of the data.
data.head()
# Out:
#          ProductId          ProfileName  HelpfulnessNumerator  \
# 498934  B000LKU3Y2              Grandma                     0
# 65087   B000EM8UFG  John B. Goode "JBG"                    14
# 431222  B000Q3CGBM             Jennifer                     0
# 403757  B003172KB6           H. Poirier                     3
# 398347  B0049PCCIA   Big Grown-Up Mommy                     1
#
#         HelpfulnessDenominator  Score             Summary  \
# 498934                       0      5    School Milk Time
# 65087                       14      5          Excellent!
# 431222                       0      5          Great food
# 403757                       4      5               Tasty
# 398347                       1      4  Nice Little Crusts
#
#                                                      Text Polarity_Rating  \
# 498934  Althought a bit expensive, this is a great alt...        Positive
# 65087   I drank Lipton's regular black tea for years b...        Positive
# 431222  My dogs love it. I own two Yorkies. The kibble...        Positive
# 403757  Got this for my sister and had a bite. As some...        Positive
# 398347  Our grocery store sells these for $5/package. ...        Positive
#
#                                                   reviews
# 498934  Althought a bit expensive this is a great alte...
# 65087   I drank Liptons regular black tea for years be...
# 431222  My dogs love it I own two Yorkies The kibble i...
# 403757  Got this for my sister and had a bite As some ...
# 398347  Our grocery store sells these for 5package The...

# %%
# Add the review data and polarity rating columns to recreate the dataset with just the needed data.
data=data[["reviews", "Polarity_Rating"]]

# Print the first few lines of the data.
data.head()
# Out:
#                                                   reviews Polarity_Rating
# 498934  Althought a bit expensive this is a great alte...        Positive
# 65087   I drank Liptons regular black tea for years be...        Positive
# 431222  My dogs love it I own two Yorkies The kibble i...        Positive
# 403757  Got this for my sister and had a bite As some ...        Positive
# 398347  Our grocery store sells these for 5package The...        Positive

# %% [markdown]
# ## One Hot Encoding

# %%
# Apply one-hot encoding to your data by using the pandas get_dummies function.
one_hot=pd.get_dummies(data["Polarity_Rating"])

# Print the first few lines of the one-hot data.
one_hot.head()
# Out:
#         Negative  Neutral  Positive
# 498934     False    False      True
# 65087      False    False      True
# 431222     False    False      True
# 403757     False    False      True
# 398347     False    False      True

# %%
# Combine your data and the one_hot data to combine the data into one big dataset.
data=pd.concat([data,one_hot], axis=1)

# Print the first few lines of the data.
data.head()
# Out:
#                                                   reviews Polarity_Rating  \
# 498934  Althought a bit expensive this is a great alte...        Positive
# 65087   I drank Liptons regular black tea for years be...        Positive
# 431222  My dogs love it I own two Yorkies The kibble i...        Positive
# 403757  Got this for my sister and had a bite As some ...        Positive
# 398347  Our grocery store sells these for 5package The...        Positive
#
#         Negative  Neutral  Positive
# 498934     False    False      True
# 65087      False    False      True
# 431222     False    False      True
# 403757     False    False      True
# 398347     False    False      True

# %%
# Drop the 'Polarity_Rating' column.
data.drop("Polarity_Rating", inplace=True,axis=1)

# Print the first few lines of the data.
data.head()
# Out:
#                                                   reviews  Negative  Neutral  \
# 498934  Althought a bit expensive this is a great alte...     False    False
# 65087   I drank Liptons regular black tea for years be...     False    False
# 431222  My dogs love it I own two Yorkies The kibble i...     False    False
# 403757  Got this for my sister and had a bite As some ...     False    False
# 398347  Our grocery store sells these for 5package The...     False    False
#
#         Positive
# 498934      True
# 65087       True
# 431222      True
# 403757      True
# 398347      True

# %% [markdown]
# ## Train and Test Split

# %%
# Set x_rev equal to the reviews column by adding .values to the end to get the data itself out of the column.
x_rev=data["reviews"].values

# Set y_pol to the data with the reviews column dropped.
y_pol = data.drop("reviews", axis=1)

# Create your train and test datasets.
x_rev_train, x_rev_test, y_pol_train, y_pol_test=train_test_split(x_rev, y_pol, test_size=0.3, shuffle=True)

# %% [markdown]
# # Vectorizing

# %% [markdown]
# ## Fit Stage

# %%
# Create a count vectorizer object.
vect=CountVectorizer()

# Set a maximum amount of features for the vectorizer to 15,000.
vect.max_features=15000

# Add the review data to the fit function.
vect.fit(x_rev)

# Get the vectorized vocabulary.
vocab=vect.vocabulary_

# Add a print statement to print out the vocab that has been saved to a variable.
print(vocab)
# Out:
# {'bit': 1836, 'expensive': 4859, 'this': 13486, 'is': 7153, 'great': 6072, 'alternative': 981, 'for': 5427, 'school': 11605, 'milk': 8375, 'if': 6792, 'you': 14928, 'have': 6345, 'child': 2727, 'on': 9240, 'the': 13410, 'diet': 3980, 'drank': 4313, 'liptons': 7765, 'regular': 10930, 'black': 1857, 'tea': 13290, 'years': 14888, 'before': 1699, 'all': 923, 'these': 13441, 'gourmet': 5987, 'happened': 6281, 'and': 1060, 'looks': 7853, 'like': 7718, 'has': 6328, 'finally': 5185, 'come': 3039, 'to': 13603, 'br': 2044, 'bought': 2009, 'mainly': 8009, 'see': 11712, 'how': 6667, 'pyramid': 10603, 'bags': 1531, 'performed': 9810, 'they': 13445, 'problem': 10398, 'with': 14740, 'flat': 5259, 'that': 13403, 'its': 7193, 'difficult': 4000, 'leaves': 7619, 'infuse': 6961, 'freely': 5535, 'due': 4385, 'of': 9168, 'shape': 11860, 'but': 2252, 'work': 14781, 'only': 9266, 'each': 4429, 'not': 8984, 'individually': 6921, 'wrapped': 14830, 'therefore': 13434, 'must': 8678, 'put': 10595, 'them': 13417, 'in': 6862, 'tight': 13550, 'container': 3247, 'prevent': 10354, 'leakage': 7601, 'flavor': 5268, 'or': 9308, 'drink': 4342, '20': 206, 'quicklybr': 10654, 'as': 1300, 'advertised': 765, 'bavarian': 1638, 'wild': 14683, 'berry': 1766, 'there': 13431, 'lot': 7874, 'actually': 690, 'can': 2340, 'taste': 13250, 'hips': 6541, 'well': 14556, 'surprising': 13088, 'since': 12068, 'ingredients': 6973, 'also': 973, 'contain': 3245, 'rosehips': 11318, 'chicory': 2724, 'root': 11313, 'cinnamon': 2825, 'bark': 1594, 'licorice': 7688, 'just': 7329, 'let': 7661, 'know': 7450, 'flavorbr': 5270, 'would': 14820, 'buy': 2268, 'it': 7171, 'again': 821, 'my': 8690, 'dogs': 4230, 'love': 7886, 'own': 9483, 'two': 13906, 'yorkies': 14926, 'kibble': 7389, 'really': 10779, 'small': 12213, 'easy': 4454, 'crunch': 3517, 'babies': 1486, 'will': 14688, 'even': 4742, 'do': 4208, 'tricks': 13810, 'mention': 8282, 'vet': 14261, 'approves': 1216, 'food': 5404, 'quality': 10622, 'got': 5979, 'sister': 12099, 'had': 6215, 'bite': 1838, 'some': 12379, 'one': 9244, 'who': 14650, 'normally': 8968, 'eats': 4467, 'gummies': 6189, 'gotta': 5983, 'say': 11558, 'thought': 13498, 'tasted': 13255, 'better': 1779, 'then': 13426, 'normal': 8966, 'sized': 12120, 'bears': 1664, 'dont': 4255, 'recommend': 10830, 'eating': 4465, 'sitting': 12108, 'our': 9387, 'grocery': 6121, 'store': 12810, 'sells': 11754, 'theyre': 13449, 'very': 14259, 'nice': 8856, 'singleserving': 12085, 'crusts': 3533, 'bake': 1539, 'up': 14082, 'about': 596, 'six': 12114, 'minutes': 8432, 'oven': 9415, 'were': 14575, 'mixed': 8472, 'family': 4988, 'everyone': 4758, 'loves': 7894, 'hand': 6252, 'quick': 10650, 'meals': 8198, 'complaint': 3106, 'be': 1648, 'size': 12118, 'vary': 14199, 'quite': 10662, 'from': 5588, 'package': 9512, 'being': 1719, 'round': 11338, 'more': 8565, 'big': 1802, 'deal': 3686, 'annoying': 1093, 'overall': 9417, 'product': 10420, 'feel': 5091, 'good': 5949, 'giving': 5850, 'because': 1677, 'are': 1238, 'healthy': 6388, 'pets': 9864, 'loved': 7888, 'presently': 10326, 'cats': 2516, 'puppy': 10558, 'share': 11866, 'treats': 13795, 'previous': 10360, 'dog': 4223, 'too': 13667, 'always': 997, 'bag': 1522, 'house': 6657, 'second': 11696, 'time': 13562, 'ordered': 9325, 'came': 2331, 'packaged': 9515, 'freezer': 5539, 'price': 10363, 'so': 12318, 'flaxseed': 5303, 'cookies': 3305, '10': 22, 'times': 13569, 'tastier': 13269, 'than': 13393, 'wheat': 14601, 'animal': 1076, 'crackers': 3415, 'little': 7794, 'boxesbr': 2035, 'animals': 1077, 'make': 8019, 'lion': 7760, 'favorite': 5053, 'zebra': 14969, 'furry': 5680, 'cat': 2502, 'circus': 2834, 'cart': 2471, 'something': 12387, 'im': 6809, 'pretty': 10350, 'sure': 13076, 'fox': 5496, 'monkey': 8542, 'lovely': 7889, 'snack': 12272, 'right': 11219, 'amount': 1040, 'definitely': 3776, 'pasta': 9659, 'any': 1134, 'relatively': 10955, 'low': 7896, 'carbs': 2421, 'helps': 6443, 'diabetic': 3948, 'oh': 9197, 'candy': 2358, 'could': 3366, 'probably': 10394, 'eat': 445 ...

# %%
# Save the vocab to your Student folder.
joblib.dump(vocab, "vocab.pkl")
# Out:
# ['vocab.pkl']

# %% [markdown]
# ## Transform

# %%
# Transform the training data.
x_rev_train_v=vect.transform(x_rev_train)

# Transform the test data.
x_rev_test_v=vect.transform(x_rev_test)

# %%
# Transform the training data into an array.
x_rev_train_v=x_rev_train_v.toarray()

# Transform the test data into an array.
x_rev_test_v=x_rev_test_v.toarray()

# %%
# Print out the shape of the training dataset.
print(x_rev_train_v.shape)

# Print the shape of the test dataset.
print(x_rev_test_v.shape)
# Out:
# (16800, 15000)
# (7200, 15000)

# %% [markdown]
# # Creating the Network

# %% [markdown]
# ## Create the Model

# %%
# Create a sequential model.
model=Sequential()

# %% [markdown]
# ## Input Layer

# %%
# Add an input layer with 4000 units and an activation of 'relu'.
model.add(Dense(units=4000, activation="relu"))

# %% [markdown]
# ## Dropout Layers

# %%
# Add a dropout layer with a rate of 0.5.
model.add(Dropout(rate=0.7))

# %% [markdown]
# ## Calculation Layers

# %%
# Add layers to the middle of the network.
model.add(Dense(activation="relu", units=2000))
model.add(Dropout(rate=0.5))
model.add(Dense(activation="relu", units=500))
model.add(Dropout(rate=0.5))
model.add(Dense(units=250, activation="relu"))
model.add(Dropout(rate=0.5))

# %% [markdown]
# ## Output Layer

# %%
# Add a final Dense layer to represent the output with the units set to 3 and activation set to "softmax".
model.add(Dense(activation="softmax", units=3))

# %% [markdown]
# ## Compiling the Network

# %%
# Add the compile function that calculates the loss and uses the optimizer parameter to set the optimization algorithm.
model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %% [markdown]
# ## Fit Data to the Network

# %%
# Add the fit function and set the input data for this model, the epochs to the fit stage, and shuffle the data, so the network doesn't rely on a pattern to learn.
model.fit(x=x_rev_train_v, y=y_pol_train, batch_size=256, epochs=10, validation_data=(x_rev_test_v, y_pol_test))
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Student\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Student\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 66/66 [==============================] - 48s 688ms/step - loss: 1.0422 - accuracy: 0.4609 - val_loss: 0.8089 - val_accuracy: 0.6465
# Epoch 2/10
# 66/66 [==============================] - 45s 676ms/step - loss: 0.7390 - accuracy: 0.6847 - val_loss: 0.7011 - val_accuracy: 0.7088
# Epoch 3/10
# 66/66 [==============================] - 43s 655ms/step - loss: 0.5340 - accuracy: 0.7854 - val_loss: 0.6931 - val_accuracy: 0.7200
# Epoch 4/10
# 66/66 [==============================] - 45s 677ms/step - loss: 0.3625 - accuracy: 0.8641 - val_loss: 0.7667 - val_accuracy: 0.7172
# Epoch 5/10
# 66/66 [==============================] - 44s 670ms/step - loss: 0.2214 - accuracy: 0.9234 - val_loss: 0.8645 - val_accuracy: 0.7197
# Epoch 6/10
# 66/66 [==============================] - 44s 666ms/step - loss: 0.1513 - accuracy: 0.9493 - val_loss: 1.0149 - val_accuracy: 0.7153
# Epoch 7/10
# 66/66 [==============================] - 43s 659ms/step - loss: 0.1033 - accuracy: 0.9681 - val_loss: 1.1264 - val_accuracy: 0.7176
# Epoch 8/10
# 66/66 [==============================] - 45s 675ms/step - loss: 0.0802 - accuracy: 0.9762 - val_loss: 1.1373 - val_accuracy: 0.7174
# Epoch 9/10
# 66/66 [==============================] - 44s 662ms/step - loss: 0.0776 - accuracy: 0.9764 - val_loss: 1.3590 - val_accuracy: 0.7133
# Epoch 10/10
# 66/66 [==============================] - 43s 657ms/step - loss: 0.0491 - accuracy: 0.9855 - val_loss: 1.3416 - val_accuracy: 0.7125

# %% [markdown]
# ## Evaluating the Network

# %%
# Calculate the scores and calculate the loss and accuracy of your model.
scores=model.evaluate(x_rev_test_v, y_pol_test, verbose=1)

# Print the test accuracy of your model.
print("Test Accuracy: ", scores[1])
# Out:
# 225/225 [==============================] - 5s 23ms/step - loss: 1.3416 - accuracy: 0.7125
# Test Accuracy:  0.7124999761581421

# %% [markdown]
# ## Save the Model

# %%
# Export your model.
model.save("sentiments.h5")
